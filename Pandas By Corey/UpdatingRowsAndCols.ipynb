# %%
import pandas as pd
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
people = {
    "first":["Corey","John","Jane"],
    "last":["Shaufer","Doe","Doe"],
    "email":["Corey@gmail.com","John@yahoo.com","Jane@ncit.edu.np"]
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last             email
# 0  Corey  Shaufer   Corey@gmail.com
# 1   John      Doe    John@yahoo.com
# 2   Jane      Doe  Jane@ncit.edu.np

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.columns = ['first_name', 'last_name', 'email']

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df.columns
# Out:
# Index(['FIRST_NAME', 'LAST_NAME', 'EMAIL'], dtype='object')

# %%
df.columns = [x.replace(" ","_") for x in df.columns]
df.columns = df.columns.str.lower()
#df.columns.str.replace(' ',' _')
df.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
df.rename(columns = {'first_name':'first','last_name':'last','email':'email'},inplace = True)

# %%
df
# Out:
#    first     last             email
# 0  Corey  Shaufer   Corey@gmail.com
# 1   John      Doe    John@yahoo.com
# 2   Jane      Doe  Jane@ncit.edu.np

# %%
df.loc[2,'last'] = 'Smith'

# %%
df
# Out:
#    first     last             email
# 0  Corey  Shaufer   Corey@gmail.com
# 1   John      Doe    John@yahoo.com
# 2   Jane      Doe  Jane@ncit.edu.np

# %%
df['email'] = df['email'].str.upper()

# %%
df
# Out:
#    first     last             email
# 0  Corey  Shaufer   COREY@GMAIL.COM
# 1   John      Doe    JOHN@YAHOO.COM
# 2   Jane      Doe  JANE@NCIT.EDU.NP

# %%
df.email = df.email.str.lower()

# %%
df
# Out:
#    first     last             email
# 0  Corey  Shaufer   Corey@gmail.com
# 1   John      Doe    John@yahoo.com
# 2   Jane      Doe  Jane@ncit.edu.np

# %%
df.loc[:,'email'].apply(len)
# Out:
# 0    15
# 1    14
# 2    16
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df.email.apply(lambda email: email.upper())
# Out:
# 0     COREY@GMAIL.COM
# 1      JOHN@YAHOO.COM
# 2    JANE@NCIT.EDU.NP
# Name: email, dtype: object

# %%
df.apply(len,axis='index')
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# first              Corey
# last                 Doe
# email    Corey@gmail.com
# dtype: object

# %%
df.apply(lambda col: col.min())
# Out:
# first              Corey
# last                 Doe
# email    Corey@gmail.com
# dtype: object

# %%
df.map(len)
# Out:
#    first  last  email
# 0      5     7     15
# 1      4     3     14
# 2      4     3     16

# %%
df.map(str.lower)
# Out:
#    first     last             email
# 0  corey  shaufer   corey@gmail.com
# 1   john      doe    john@yahoo.com
# 2   jane      doe  jane@ncit.edu.np

# %%
df.loc[:,'first'].map({'Corey':'Arthur'})
# Out:
# 0    Arthur
# 1       NaN
# 2       NaN
# Name: first, dtype: object

# %%
df['first'].replace({'Corey':'Arthur'})
# Out:
# 0    Arthur
# 1      John
# 2      Jane
# Name: first, dtype: object
