# %%
import pandas as pd
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
people = {
    "first":["Corey","John","Jane"],
    "last":["Shaufer","Doe","Doe"],
    "email":["Corey@gmail.com","John@yahoo.com","Jane@ncit.edu.np"]
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last             email
# 0  Corey  Shaufer   Corey@gmail.com
# 1   John      Doe    John@yahoo.com
# 2   Jane      Doe  Jane@ncit.edu.np

# %%
df.email
# Out:
# 0     Corey@gmail.com
# 1      John@yahoo.com
# 2    Jane@ncit.edu.np
# Name: email, dtype: object

# %%
df.set_index("email",inplace = True)

# %%
df
# Out:
#                   first     last
# email
# Corey@gmail.com   Corey  Shaufer
# John@yahoo.com     John      Doe
# Jane@ncit.edu.np   Jane      Doe

# %%
df.loc['Corey@gmail.com','first']
# Out:
# 'Corey'

# %%
df.iloc[0]
# Out:
# first      Corey
# last     Shaufer
# Name: Corey@gmail.com, dtype: object
