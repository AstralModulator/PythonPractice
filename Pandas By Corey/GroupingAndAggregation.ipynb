# %%
import pandas as pd
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
results = pd.read_csv(r"C:\Users\HP\Downloads\stack-overflow-developer-survey-2019\survey_results_public.csv",index_col=0)
schema_df = pd.read_csv(r"C:\Users\HP\Downloads\stack-overflow-developer-survey-2019\survey_results_schema.csv")

# %%
results.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
results.SocialMedia.value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
results.groupby('Country').SocialMedia.value_counts().sort_values()
# Out:
# Country        SocialMedia
# Ukraine        WeChat 微信         1
# Georgia        Instagram         1
# Afghanistan    Instagram         1
#                LinkedIn          1
#                Twitter           1
#                               ...
# United States  YouTube        2463
#                Facebook       2844
# India          WhatsApp       2990
# United States  Twitter        3468
#                Reddit         5700
# Name: count, Length: 1220, dtype: int64

# %%
group = results.groupby('Country')

# %%
group.ConvertedComp.value_counts().sort_index(ascending=[True,False])
# Out:
# Country      ConvertedComp
# Afghanistan  1000000.0        1
#              153216.0         1
#              19152.0          1
#              17556.0          1
#              14364.0          1
#                              ..
# Zimbabwe     15000.0          1
#              12000.0          2
#              7800.0           1
#              6000.0           1
#              900.0            1
# Name: count, Length: 15016, dtype: int64

# %%
group.SocialMedia.value_counts().loc['Nepal']
# Out:
# SocialMedia
# YouTube                     95
# Facebook                    71
# LinkedIn                    22
# Twitter                     16
# Reddit                       9
# Instagram                    8
# WhatsApp                     5
# I don't use social media     4
# WeChat 微信                    1
# Name: count, dtype: int64

# %%
results.Country.value_counts(normalize = True)*100
# Out:
# Country
# United States                       23.604241
# India                               10.209462
# Germany                              6.609503
# United Kingdom                       6.464153
# Canada                               3.825309
#                                       ...
# Papua New Guinea                     0.001127
# Saint Kitts and Nevis                0.001127
# Saint Vincent and the Grenadines     0.001127
# Sao Tome and Principe                0.001127
# Chad                                 0.001127
# Name: proportion, Length: 179, dtype: float64

# %%
group.ConvertedComp.mean().sort_values(ascending = False)
# Out:
# Country
# Liechtenstein            811188.000000
# San Marino               301788.000000
# Ireland                  250342.239067
# United States            249546.254589
# Swaziland                242607.500000
#                              ...
# Papua New Guinea                   NaN
# Saint Kitts and Nevis              NaN
# Sao Tome and Principe              NaN
# Sierra Leone                       NaN
# Tonga                              NaN
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
group.get_group('Liechtenstein')
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 4434                I am a developer by profession      Yes
# 25380               I am a developer by profession      Yes
# 78838       I am a student who is learning to code       No
#
#                                                   OpenSourcer  \
# Respondent
# 4434                                  Less than once per year
# 25380       Less than once a month but more than once per ...
# 78838       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 4434        OSS is, on average, of HIGHER quality than pro...
# 25380       The quality of OSS and closed source software ...
# 78838       The quality of OSS and closed source software ...
#
#                                                    Employment        Country  \
# Respondent
# 4434                                       Employed full-time  Liechtenstein
# ...

# %%
group.SocialMedia.value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: count, Length: 1220, dtype: int64

# %%
group.ConvertedComp.agg(['min','max','median']).loc['Nepal']
# Out:
# min            0.0
# max       300000.0
# median      4224.0
# Name: Nepal, dtype: float64

# %%
results.LanguageWorkedWith.str.contains('Python',na=False).sum()
# Out:
# np.int64(36443)

# %%
group.apply(lambda df: df[df.LanguageWorkedWith.str.contains('Python',na=False)])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24476\1266524725.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group.apply(lambda df: df[df.LanguageWorkedWith.str.contains('Python',na=False)])
#                                                                MainBranch  \
# Country     Respondent
# Afghanistan 10746                          I am a developer by profession
#             29045       I am not primarily a developer, but I write co...
#             40000                  I am a student who is learning to code
#             59560                  I am a student who is learning to code
#             60569                  I am a student who is learning to code
# ...

# %%
group.apply(lambda df: df[df.LanguageWorkedWith.str.contains('Python',na=False)].)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24476\3824141261.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group.apply(lambda df: df.LanguageWorkedWith.str.contains('Python',na=False).sum())
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# ...

# %%
group.LanguageWorkedWith.apply(lambda df: df.str.contains('Python',na=False).sum()/df.str.contains('Python').count() *100 )
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24476\2729338918.py:1: RuntimeWarning: invalid value encountered in scalar divide
#   group.LanguageWorkedWith.apply(lambda df: df.str.contains('Python',na=False).sum()/df.str.contains('Python').count() *100 )
# Country
# Afghanistan                             20.512821
# Albania                                 27.710843
# Algeria                                 31.746032
# Andorra                                  0.000000
# Angola                                  50.000000
#                                           ...
# Venezuela, Bolivarian Republic of...    32.183908
# Viet Nam                                35.454545
# Yemen                                   17.647059
# Zambia                                  33.333333
# Zimbabwe                                35.897436
# Name: LanguageWorkedWith, Length: 179, dtype: float64

# %%
know_python = group.apply(lambda df:df.LanguageWorkedWith.str.contains('Python',na=False).sum())
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24476\3219878262.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   know_python = group.apply(lambda df:df.LanguageWorkedWith.str.contains('Python',na=False).sum())

# %%
country_count = results.Country.value_counts()

# %%
combine = pd.concat([know_python,country_count],axis = 1)

# %%
combine
# Out:
#                                        0  count
# Country
# Afghanistan                            8     44
# Albania                               23     86
# Algeria                               40    134
# Andorra                                0      7
# Angola                                 2      5
# ...                                   ..    ...
# Venezuela, Bolivarian Republic of...  28     88
# Viet Nam                              78    231
# Yemen                                  3     19
# Zambia                                 4     12
# Zimbabwe                              14     39
#
# [179 rows x 2 columns]

# %%
combine.rename(columns = {0:'countless'},inplace = True)

# %%
combine['percentage'] = (combine['countless'])/combine['count'] *100

# %%
combine
# Out:
#                                       countless  count  percentage
# Country
# Afghanistan                                   8     44   18.181818
# Albania                                      23     86   26.744186
# Algeria                                      40    134   29.850746
# Andorra                                       0      7    0.000000
# Angola                                        2      5   40.000000
# ...                                         ...    ...         ...
# Venezuela, Bolivarian Republic of...         28     88   31.818182
# Viet Nam                                     78    231   33.766234
# Yemen                                         3     19   15.789474
# Zambia                                        4     12   33.333333
# Zimbabwe                                     14     39   35.897436
#
# [179 rows x 3 columns]

# %%
combine.sort_values(by='percentage', ascending = False).head(50)
# Out:
#                                   countless  count  percentage
# Country
# Dominica                                  1      1  100.000000
# Sao Tome and Principe                     1      1  100.000000
# Niger                                     1      1  100.000000
# Timor-Leste                               1      1  100.000000
# Turkmenistan                              6      7   85.714286
# Mauritania                                5      7   71.428571
# Guinea                                    2      3   66.666667
# Bahamas                                   2      3   66.666667
# Guyana                                    2      3   66.666667
# Uganda                                   47     72   65.277778
# Iceland                                  30     49   61.224490
# Namibia                                   3      5   60.000000
# Haiti                                     3      5   60.000000
# Benin                                     3      5   60.000000
# ...

# %%
group.ConvertedComp.apply(lambda col: col -col.mean())
# Out:
# Country      Respondent
# Afghanistan  722          -101953.333333
#              6417                    NaN
#              7085          -87589.333333
#              7353                    NaN
#              8149         -100357.333333
#                                ...
# Zimbabwe     76594          35953.333333
#              77533                   NaN
#              82752          -5246.666667
#              83850          10953.333333
#              84155         -22046.666667
# Name: ConvertedComp, Length: 88751, dtype: float64

# %%
hello = group.LanguageWorkedWith.apply(lambda col: col.str.contains('Python',na=False).sum())

# %%
hell = group.Country.count()

# %%
df = pd.concat([hello,hell],axis=1,sort=False)

# %%
df
# Out:
#                                       LanguageWorkedWith  Country
# Country
# Afghanistan                                            8       44
# Albania                                               23       86
# Algeria                                               40      134
# Andorra                                                0        7
# Angola                                                 2        5
# ...                                                  ...      ...
# Venezuela, Bolivarian Republic of...                  28       88
# Viet Nam                                              78      231
# Yemen                                                  3       19
# Zambia                                                 4       12
# Zimbabwe                                              14       39
#
# [179 rows x 2 columns]

# %%
df['percentage'] = df['LanguageWorkedWith']/df['Country'] * 100

# %%
df
# Out:
#                                       LanguageWorkedWith  Country  percentage
# Country
# Afghanistan                                            8       44   18.181818
# Albania                                               23       86   26.744186
# Algeria                                               40      134   29.850746
# Andorra                                                0        7    0.000000
# Angola                                                 2        5   40.000000
# ...                                                  ...      ...         ...
# Venezuela, Bolivarian Republic of...                  28       88   31.818182
# Viet Nam                                              78      231   33.766234
# Yemen                                                  3       19   15.789474
# Zambia                                                 4       12   33.333333
# Zimbabwe                                              14       39   35.897436
#
# [179 rows x 3 columns]

# %%
df['percentage'] = df.LanguageWorkedWith - df.LanguageWorkedWith

# %%
group.LanguageWorkedWith.apply(lambda col: col.str.contains('Python',na=False).sum()/len(col)*100)
# Out:
# Country
# Afghanistan                             18.181818
# Albania                                 26.744186
# Algeria                                 29.850746
# Andorra                                  0.000000
# Angola                                  40.000000
#                                           ...
# Venezuela, Bolivarian Republic of...    31.818182
# Viet Nam                                33.766234
# Yemen                                   15.789474
# Zambia                                  33.333333
# Zimbabwe                                35.897436
# Name: LanguageWorkedWith, Length: 179, dtype: float64

# %%
group = results.groupby('Country')

# %%
df2 = group.LanguageWorkedWith.apply(len)

# %%
df1 = group.LanguageWorkedWith.apply(lambda col: col.str.contains('Python',na=False).sum())

# %%
df1.name = 'KnowsPython'

# %%
df = pd.concat([df1,df2],axis=1,sort=False)

# %%
df
# Out:
#                                       KnowsPython  LanguageWorkedWith
# Country
# Afghanistan                                     8                  44
# Albania                                        23                  86
# Algeria                                        40                 134
# Andorra                                         0                   7
# Angola                                          2                   5
# ...                                           ...                 ...
# Venezuela, Bolivarian Republic of...           28                  88
# Viet Nam                                       78                 231
# Yemen                                           3                  19
# Zambia                                          4                  12
# Zimbabwe                                       14                  39
#
# [179 rows x 2 columns]

# %%
df['percentage'] = df['KnowsPython']/df['LanguageWorkedWith'] * 100

# %%
df
# Out:
#                                       KnowsPython  LanguageWorkedWith  \
# Country
# Afghanistan                                     8                  44
# Albania                                        23                  86
# Algeria                                        40                 134
# Andorra                                         0                   7
# Angola                                          2                   5
# ...                                           ...                 ...
# Venezuela, Bolivarian Republic of...           28                  88
# Viet Nam                                       78                 231
# Yemen                                           3                  19
# Zambia                                          4                  12
# Zimbabwe                                       14                  39
#
#                                       percentage
# Country
# Afghanistan                            18.181818
# ...

# %%
group.LanguageWorkedWith.apply(lambda col: col.str.contains('Python',na=False).sum()/len(col) * 100)
# Out:
# Country
# Afghanistan                             18.181818
# Albania                                 26.744186
# Algeria                                 29.850746
# Andorra                                  0.000000
# Angola                                  40.000000
#                                           ...
# Venezuela, Bolivarian Republic of...    31.818182
# Viet Nam                                33.766234
# Yemen                                   15.789474
# Zambia                                  33.333333
# Zimbabwe                                35.897436
# Name: LanguageWorkedWith, Length: 179, dtype: float64

# %%
group.LanguageWorkedWith.apply(len)
# Out:
# Country
# Afghanistan                              44
# Albania                                  86
# Algeria                                 134
# Andorra                                   7
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     88
# Viet Nam                                231
# Yemen                                    19
# Zambia                                   12
# Zimbabwe                                 39
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
group.LanguageWorkedWith.apply(lambda col:col.str.contains('Python',na=False).sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
group.LanguageWorkedWith.apply(lambda col: col.str.contains('Python',na=False).sum()/len(col) * 100)
# Out:
# Country
# Afghanistan                             18.181818
# Albania                                 26.744186
# Algeria                                 29.850746
# Andorra                                  0.000000
# Angola                                  40.000000
#                                           ...
# Venezuela, Bolivarian Republic of...    31.818182
# Viet Nam                                33.766234
# Yemen                                   15.789474
# Zambia                                  33.333333
# Zimbabwe                                35.897436
# Name: LanguageWorkedWith, Length: 179, dtype: float64
