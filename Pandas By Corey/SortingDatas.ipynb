# %%
import pandas as pd

# %%
people = {
    "first":["Corey","John","Jane",'Adam'],
    "last":["Shaufer","Doe","Doe",'Doe'],
    "email":["Corey@gmail.com","John@yahoo.com","Jane@ncit.edu.np",'DoeAdam@gmail.com']
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last             email
# 0  Corey  Shaufer   Corey@gmail.com
# 1   John      Doe    John@yahoo.com
# 2   Jane      Doe  Jane@ncit.edu.np

# %%
df.sort_values(by='last')
# Out:
#    first     last             email
# 1   John      Doe    John@yahoo.com
# 2   Jane      Doe  Jane@ncit.edu.np
# 0  Corey  Shaufer   Corey@gmail.com

# %%
df.sort_values(by=['last','first'],ascending=[False,True],inplace=True,ignore_index=True)

# %%
df
# Out:
#    first     last              email
# 0  Corey  Shaufer    Corey@gmail.com
# 1   Adam      Doe  DoeAdam@gmail.com
# 2   Jane      Doe   Jane@ncit.edu.np
# 3   John      Doe     John@yahoo.com
