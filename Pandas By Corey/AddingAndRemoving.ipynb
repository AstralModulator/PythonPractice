# %%
import pandas as pd
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
people = {
    "first": ["Corey", "John", "Jane"],
    "last": ["Shaufer", "Doe", "Doe"],
    "email": ["Corey@gmail.com", "John@yahoo.com", "Jane@ncit.edu.np"]
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last             email
# 0  Corey  Shaufer   Corey@gmail.com
# 1   John      Doe    John@yahoo.com
# 2   Jane      Doe  Jane@ncit.edu.np

# %%
df['full_name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#               email  first     last      full_name
# 0   Corey@gmail.com  Corey  Shaufer  Corey Shaufer
# 1    John@yahoo.com   John      Doe       John Doe
# 2  Jane@ncit.edu.np   Jane      Doe       Jane Doe

# %%
df.drop(columns=['first','last'],inplace = True)

# %%
df
# Out:
#               email      full_name
# 0   Corey@gmail.com  Corey Shaufer
# 1    John@yahoo.com       John Doe
# 2  Jane@ncit.edu.np       Jane Doe

# %%
df.full_name.str.split(' ',expand=True)
# Out:
#        0        1
# 0  Corey  Shaufer
# 1   John      Doe
# 2   Jane      Doe

# %%
df[['first','last']] = df.full_name.str.split(' ',expand=True)

# %%
df
# Out:
#               email      full_name  first     last
# 0   Corey@gmail.com  Corey Shaufer  Corey  Shaufer
# 1    John@yahoo.com       John Doe   John      Doe
# 2  Jane@ncit.edu.np       Jane Doe   Jane      Doe

# %%
df.drop('full_name',axis=1,inplace=True)

# %%
df
# Out:
#               email  first     last
# 0   Corey@gmail.com  Corey  Shaufer
# 1    John@yahoo.com   John      Doe
# 2  Jane@ncit.edu.np   Jane      Doe

# %%
df = pd.concat([df,pd.DataFrame({'email':['dip.231512@ncit.edu.np'],'first':['Dip Kiran']})],sort=False,ignore_index=True)

# %%
df
# Out:
#                     email      first     last
# 0         Corey@gmail.com      Corey  Shaufer
# 1          John@yahoo.com       John      Doe
# 2        Jane@ncit.edu.np       Jane      Doe
# 3  dip.231512@ncit.edu.np  Dip Kiran      NaN

# %%
df['full_name'] = df['first'] + df['last']

# %%
df
# Out:
#        first     last                   email     full_name
# 0      Corey  Shaufer         Corey@gmail.com  CoreyShaufer
# 1       John      Doe          John@yahoo.com       JohnDoe
# 2       Jane      Doe        Jane@ncit.edu.np       JaneDoe
# 3  Dip Kiran      NaN  dip.231512@ncit.edu.np           NaN

# %%
df = pd.concat([df,pd.Series([1,2,3,4],name="ID")],axis = 1)

# %%
df
# Out:
#        first     last                   email     full_name  ID
# 0      Corey  Shaufer         Corey@gmail.com  CoreyShaufer   1
# 1       John      Doe          John@yahoo.com       JohnDoe   2
# 2       Jane      Doe        Jane@ncit.edu.np       JaneDoe   3
# 3  Dip Kiran      NaN  dip.231512@ncit.edu.np           NaN   4

# %%
df.set_index("ID",inplace = True)

# %%
df
# Out:
#         first     last                   email     full_name
# ID
# 1       Corey  Shaufer         Corey@gmail.com  CoreyShaufer
# 2        John      Doe          John@yahoo.com       JohnDoe
# 3        Jane      Doe        Jane@ncit.edu.np       JaneDoe
# 4   Dip Kiran      NaN  dip.231512@ncit.edu.np           NaN
