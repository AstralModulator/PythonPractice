# %%
import pandas as pd
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
results = pd.read_csv(r"C:\Users\HP\Downloads\stack-overflow-developer-survey-2019\survey_results_public.csv",index_col=0)
schema_df = pd.read_csv(r"C:\Users\HP\Downloads\stack-overflow-developer-survey-2019\survey_results_schema.csv")

# %%
results.sort_values(by='Country',inplace=True)

# %%
results.Country.head(50)
# Out:
# Respondent
# 39258    Afghanistan
# 63129    Afghanistan
# 85715    Afghanistan
# 50767    Afghanistan
# 2782     Afghanistan
# 63019    Afghanistan
# 6417     Afghanistan
# 40000    Afghanistan
# 88731    Afghanistan
# 48436    Afghanistan
# 10746    Afghanistan
# 62525    Afghanistan
# 49702    Afghanistan
# 33178    Afghanistan
# 60946    Afghanistan
# 86362    Afghanistan
# 88582    Afghanistan
# 28638    Afghanistan
# 722      Afghanistan
# 26340    Afghanistan
# 86932    Afghanistan
# 85825    Afghanistan
# 7085     Afghanistan
# 7353     Afghanistan
# 87091    Afghanistan
# 58760    Afghanistan
# 74386    Afghanistan
# 29045    Afghanistan
# 51859    Afghanistan
# 45854    Afghanistan
# 47110    Afghanistan
# 44403    Afghanistan
# 22450    Afghanistan
# 8149     Afghanistan
# 80926    Afghanistan
# 59560    Afghanistan
# 60569    Afghanistan
# 37802    Afghanistan
# 29736    Afghanistan
# 43106    Afghanistan
# 12310    Afghanistan
# 58450    Afghanistan
# ...

# %%
results.sort_values(by=['Country','Salary'],ascending=[True,False],inplace=True)

# %%
results.rename(columns={'ConvertedComp':'Salary'},inplace=True)

# %%
results.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq', 'Salary',
#        'WorkWeekHrs', 'WorkPlan', 'WorkChallenge', 'WorkRemote', 'WorkLoc',
#        'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow',
#        'PurchaseWhat', 'LanguageWorkedWith', 'LanguageDesireNextYear',
#        'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
results[['Salary','Country']].head(50)
# Out:
#                Salary      Country
# Respondent
# 63129       1000000.0  Afghanistan
# 50499        153216.0  Afghanistan
# 39258         19152.0  Afghanistan
# 58450         17556.0  Afghanistan
# 7085          14364.0  Afghanistan
# 22450          7980.0  Afghanistan
# 48436          4464.0  Afghanistan
# 10746          3996.0  Afghanistan
# 8149           1596.0  Afghanistan
# 29736          1116.0  Afghanistan
# 28638             0.0  Afghanistan
# 722               0.0  Afghanistan
# 85715             NaN  Afghanistan
# 50767             NaN  Afghanistan
# 2782              NaN  Afghanistan
# 63019             NaN  Afghanistan
# 6417              NaN  Afghanistan
# 40000             NaN  Afghanistan
# 88731             NaN  Afghanistan
# 62525             NaN  Afghanistan
# 49702             NaN  Afghanistan
# 33178             NaN  Afghanistan
# 60946             NaN  Afghanistan
# 86362             NaN  Afghanistan
# 88582             NaN  Afghanistan
# ...

# %%
results.rename(columns={'ConvertedComp':'Salary'},inplace=True)

# %%
results.nsmallest(100,'Salary')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 722         I am a developer by profession       No
# 28638       I am a developer by profession      Yes
# 13825       I am a developer by profession      Yes
# 40913       I am a developer by profession      Yes
# 30630       I am a developer by profession      Yes
# ...                                    ...      ...
# 62880       I am a developer by profession       No
# 63710       I am a developer by profession       No
# 64479       I am a developer by profession      Yes
# 65176       I am a developer by profession       No
# 65453       I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 722         Less than once a month but more than once per ...
# 28638       Less than once a month but more than once per ...
# 13825                                                   Never
# ...
