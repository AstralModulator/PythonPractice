# %%
import matplotlib.pyplot as plt

# %%
sem = [1,2,3,4]
res = [4,3.91,3.85,3.74]

# %%
plt.figure(figsize = (14,6))
plt.plot(sem,res)
plt.show()

# %%
plt.scatter(sem,res)
plt.show()

# %%
res = [3.72,3.56,3.4,0]
plt.figure(figsize = (14,6))
plt.plot(sem,res)
plt.show()
