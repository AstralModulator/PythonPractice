# %%
import matplotlib.pyplot as plt

# %%
sem = [1,2,3,4]
res = [4,3.91,3.85,3.74]

# %%
plt.figure(figsize=(8,6))
plt.plot(sem,res,'o')
plt.grid()
plt.xlabel("Semester")
plt.ylabel('Result')
plt.title("comparing Semesters results")
plt.show()
